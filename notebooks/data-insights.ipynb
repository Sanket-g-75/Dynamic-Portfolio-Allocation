# %%
import os

import pandas as pd 
import numpy as np

from data import itemset  # can directly import from the folder by defining the folder name

# %%
os.chdir(r"D:\1.Work\WorkStation\WorkSpace\Projects\Dynamic-Portfolio-Allocation")
path = os.getcwd()

# %%
nvidia_path = os.path.join(path,'data',f'{itemset.stocks[0]}.csv')

# %%
nvidia = pd.read_csv(nvidia_path)

# %%
nvidia = nvidia.iloc[2:,:]

# %%
nvidia.rename(columns={'Price':'Date'},inplace=True)
nvidia['Date'] = pd.to_datetime(nvidia['Date'])
nvidia.set_index('Date')
# Out:
# C:\Users\Sanket\AppData\Local\Temp\ipykernel_15024\484107173.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nvidia.rename(columns={'Price':'Date'},inplace=True)

# %%
# Out:
# C:\Users\Sanket\AppData\Local\Temp\ipykernel_15024\3036165941.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nvidia['Date'] = pd.to_datetime(nvidia['Date'])

# %%
# Out:
#                          Close Dividends                High  \
# Date
# 2015-12-28  0.8083701133728027       0.0  0.8083701133728027
# 2015-12-29  0.8215419054031372       0.0  0.8239811604936232
# 2015-12-30  0.8144680857658386       0.0  0.8278840184606137
# 2015-12-31  0.8039794564247131       0.0   0.816907517611796
# 2016-01-04  0.7895879149436951       0.0  0.7947103350807067
# ...                        ...       ...                 ...
# 2025-12-18  174.13999938964844       0.0  176.14999389648438
# 2025-12-19  180.99000549316406       0.0   181.4499969482422
# 2025-12-22  183.69000244140625       0.0  184.16000366210938
# 2025-12-23   189.2100067138672       0.0   189.3300018310547
# 2025-12-24  188.61000061035156       0.0  188.91000366210938
#
#                            Low                Open Stock Splits     Volume
# Date
# 2015-12-28  0.7893439414695138  0.8005645297370835          0.0  142024000
# ...
